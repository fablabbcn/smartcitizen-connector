# %%
from smartcitizen_connector import UserHandler, search_by_query

# %%
df = search_by_query('users', search_items=[{'key': 'username', 'value': 'Adai', 'search_matcher':'cont'}])

df.username

# %%
u = UserHandler(8504)

# %%
u.get()

# %%
print (f'User: {u.model.username} - Location: {u.model.location.city}')
for d in u.model.devices:
    print (d.id, 'online' if 'online' in d.system_tags else 'offline')
print ('-----')
print (f'Total devices: {len(u.model.devices)}')
